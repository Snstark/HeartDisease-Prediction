# %% [markdown]
# This dataset is Heart Diesase Rate Prediction Data.
#
# Already a Well CLeaned Dataset.
#
# Data Set : taken from Kaggle.

# %% [markdown]
# According to the CDC, heart disease is one of the leading causes of death for people of most races in the US (African Americans, American Indians and Alaska Natives, and white people). About half of all Americans (47%) have at least 1 of 3 key risk factors for heart disease: high blood pressure, high cholesterol, and smoking. Other key indicator include diabetic status, obesity (high BMI), not getting enough physical activity or drinking too much alcohol. Detecting and preventing the factors that have the greatest impact on heart disease is very important in healthcare. Computational developments, in turn, allow the application of machine learning methods to detect "patterns" from the data that can predict a patient's condition.
#
#
# Explanation of the variables of the dataset
#
# HeartDisease : Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI).
#
# BMI : Body Mass Index (BMI).
#
# Smoking : Have you smoked at least 100 cigarettes in your entire life? ( The answer Yes or No ).
#
# AlcoholDrinking : Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week
#
# Stroke : (Ever told) (you had) a stroke?
#
# PhysicalHealth : Now thinking about your physical health, which includes physical illness and injury, for how many days during the past 30 days was your physical health not good? (0-30 days).
#
# MentalHealth : Thinking about your mental health, for how many days during the past 30 days was your mental health not good? (0-30 days).
#
# DiffWalking : Do you have serious difficulty walking or climbing stairs?
#
# Sex : Are you male or female?
#
# AgeCategory: Fourteen-level age category.
#
# Race : Imputed race/ethnicity value.
#
# Diabetic : (Ever told) (you had) diabetes?
#
# PhysicalActivity : Adults who reported doing physical activity or exercise during the past 30 days other than their regular job.
#
# GenHealth : Would you say that in general your health is...
#
# SleepTime : On average, how many hours of sleep do you get in a 24-hour period?
#
# Asthma : (Ever told) (you had) asthma?
#
# KidneyDisease : Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?
#
# SkinCancer : (Ever told) (you had) skin cancer?

# %%
#importing necesssary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
import plotly.offline as py

# %%
df= pd.read_csv("heart_2020_cleaned.csv")
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.title("Plot of Heart Disease Based on  Gender")
sns.countplot(x=df['Sex'],hue=df['HeartDisease'])
# Out:
# <AxesSubplot:title={'center':'Plot of Heart Disease Based on  Gender'}, xlabel='Sex', ylabel='count'>

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
plt.figure(figsize=(10,5))
plt.title("Plot of Heart Disease Based on  Smoking")
sns.countplot(x=df['Smoking'],hue=df['HeartDisease'])
# Out:
# <AxesSubplot:title={'center':'Plot of Heart Disease Based on  Smoking'}, xlabel='Smoking', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
plt.title("Hist Plot of BMI")
sns.histplot(df['BMI'])
# Out:
# <AxesSubplot:title={'center':'Hist Plot of BMI'}, xlabel='BMI', ylabel='Count'>

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
# setting the size of the plot
plt.rcParams['figure.figsize'] = (9, 4)

# plotting a simple count plot
sns.countplot(x=df['GenHealth'])
plt.xticks(rotation = 375)
plt.show()

# %%
sns.pairplot(df)

# %%
plt.rcParams['figure.figsize'] = (9, 4)

# plotting a simple count plot
sns.countplot(x=df['AgeCategory'],hue=df['HeartDisease'])
plt.xticks(rotation = 375)
plt.show()

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
plt.rcParams['figure.figsize'] = (9, 4)
plt.title("Diabetic Vs Heart Disease")
sns.countplot(x=df['Diabetic'],hue=df['HeartDisease'])
# Out:
# <AxesSubplot:title={'center':'Diabetic Vs Heart Disease'}, xlabel='Diabetic', ylabel='count'>

# %%
plt.rcParams['figure.figsize'] = (9, 4)
plt.title("SkinCancer Vs Heart Disease")
sns.countplot(x=df['SkinCancer'],hue=df['HeartDisease'])
# Out:
# <AxesSubplot:title={'center':'SkinCancer Vs Heart Disease'}, xlabel='SkinCancer', ylabel='count'>

# %%
plt.rcParams['figure.figsize'] = (9, 4)
plt.title("Asthma Vs Heart Disease")
sns.countplot(x=df['Asthma'],hue=df['HeartDisease'])
# Out:
# <AxesSubplot:title={'center':'Asthma Vs Heart Disease'}, xlabel='Asthma', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
plt.title("Sleep Time Vs ")
sns.countplot(x= df['SleepTime'])
# Out:
# <AxesSubplot:title={'center':'Sleep Time Vs '}, xlabel='SleepTime', ylabel='count'>

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
plt.figure(figsize = (13,6))
plt.title("Plot between Race Vs Count with Hue of HeartDisease")
sns.countplot( x= df['Race'], hue = 'HeartDisease', data = df)
plt.xlabel('Race')
plt.ylabel('Frequency')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 4)
sns.countplot(x = df['AgeCategory'], hue = df['HeartDisease'])
plt.suptitle("Distribution of Cases with Yes/No heartdisease according to AgeCategory")
plt.xlabel('AgeCategory')
plt.ylabel('Frequency')
plt.show()

# %%
dict1 ={"Yes":1,"No":0}

# %%
df['DiffWalking'] =df['DiffWalking'].replace(dict1)

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth  DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0            0  Female        55-59  White      Yes
# 1           0.0            0  Female  80 or older  White       No
# 2          30.0            0    Male        65-69  White      Yes
# 3           0.0            0  Female        75-79  White       No
# 4           0.0            1  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  int64
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  object
# ...

# %%
df.AgeCategory.value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %%
dict2 ={"65-69":1,"60-64":2,"70-74":3,"55-59":4,"50-54":5,"80 or older":6,
        "45-49":7,"75-79":8,"18-24":9,"40-44":10,"35-39":11,"30-34":12,"25-29":13}

# %%
df['AgeCategory'] =df['AgeCategory'].replace(dict2)

# %%
dict3 = {"Yes":1,"No":0}

# %%
df['HeartDisease']=df['HeartDisease'].replace(dict3)

# %%
df.head()
# Out:
#    HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0             0  16.60     Yes              No     No             3.0
# 1             0  20.34      No              No    Yes             0.0
# 2             0  26.58     Yes              No     No            20.0
# 3             0  24.21      No              No     No             0.0
# 4             0  23.71      No              No     No            28.0
#
#    MentalHealth  DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0            0  Female            4  White      Yes
# 1           0.0            0  Female            6  White       No
# 2          30.0            0    Male            1  White      Yes
# 3           0.0            0  Female            8  White       No
# 4           0.0            1  Female           10  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df['Smoking'] = df['Smoking'].replace(dict3)

# %%
df['AlcoholDrinking'] =df['AlcoholDrinking'].replace(dict3)

# %%
df['Stroke'] = df['Stroke'].replace(dict3)

# %%
dict4 ={"Male":1,"Female":0}

# %%
df['Sex'] =df['Sex'].replace(dict4)

# %%
dict5 = {"No":2,"Yes":1,"No, borderline diabetes":4,"Yes (during pregnancy)":3}

# %%
df['Diabetic'] = df['Diabetic'].replace(dict5)

# %%
df['Asthma'] = df['Asthma'].replace(dict3)

# %%
df['KidneyDisease'] = df['KidneyDisease'].replace(dict3)

# %%
df['SkinCancer'] = df['SkinCancer'].replace(dict3)

# %%
dict6 = {"Very good":5,"Good":4,"Excellent":3,"Fair":2,"Poor":1}

# %%
df['GenHealth'] = df['GenHealth'].replace(dict6)

# %%
df['PhysicalActivity'] = df['PhysicalActivity'].replace(dict3)

# %%
dict7 ={"White":1,"Hispanic":2,"Black":3,"Other":4,"Asian":5,"American Indian/Alaskan Native":6}

# %%
df['Race'] = df['Race'].replace(dict7)

# %%
df.describe().T
# Out:
#                      count       mean       std    min    25%    50%    75%  \
# HeartDisease      319795.0   0.085595  0.279766   0.00   0.00   0.00   0.00
# BMI               319795.0  28.325399  6.356100  12.02  24.03  27.34  31.42
# Smoking           319795.0   0.412477  0.492281   0.00   0.00   0.00   1.00
# AlcoholDrinking   319795.0   0.068097  0.251912   0.00   0.00   0.00   0.00
# Stroke            319795.0   0.037740  0.190567   0.00   0.00   0.00   0.00
# PhysicalHealth    319795.0   3.371710  7.950850   0.00   0.00   0.00   2.00
# MentalHealth      319795.0   3.898366  7.955235   0.00   0.00   0.00   3.00
# DiffWalking       319795.0   0.138870  0.345812   0.00   0.00   0.00   0.00
# Sex               319795.0   0.475273  0.499389   0.00   0.00   0.00   1.00
# AgeCategory       319795.0   6.194919  3.733510   1.00   3.00   6.00   9.00
# Race              319795.0   1.514048  1.107419   1.00   1.00   1.00   1.00
# ...

# %% [markdown]
# UnderWeight : below 19
#
# Healthweight: 20-24
#
# Overweight  : 25-29
#
# Significantly overweight : 30-39
#
# Dangerously overweight : 40-63

# %%
#Pairplot and Relation Between Target and Other Columns to find the Better Features
plt.figure(figsize=(14,10))
sns.pairplot(df,x_vars=['BMI', 'Smoking', 'AlcoholDrinking', 'Stroke','PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex',
       'Diabetic', 'PhysicalActivity', 'SleepTime','Asthma', 'KidneyDisease', 'SkinCancer'],y_vars='HeartDisease',height = 4,aspect = 0.5,kind='reg')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  int64
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  int64
#  3   AlcoholDrinking   319795 non-null  int64
#  4   Stroke            319795 non-null  int64
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  int64
#  8   Sex               319795 non-null  int64
#  9   AgeCategory       319795 non-null  int64
#  10  Race              319795 non-null  int64
#  11  Diabetic          319795 non-null  int64
#  12  PhysicalActivity  319795 non-null  int64
#  13  GenHealth         319795 non-null  int64
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  int64
# ...

# %%
plt.figure(figsize=(14,8))
sns.pairplot(df,x_vars=['AgeCategory','GenHealth'],y_vars='HeartDisease',height = 4,aspect = 0.5,kind='reg')

# %%
plt.figure(figsize=(14,8))
sns.pairplot(df,x_vars=['Race'],y_vars='HeartDisease',height = 4,aspect = 0.5,kind='reg')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,linewidths=3,linecolor="black",cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
X=df.drop(columns=["HeartDisease","Race"])
X
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0             3.0          30.0
# 1       20.34        0                0       1             0.0           0.0
# 2       26.58        1                0       0            20.0          30.0
# 3       24.21        0                0       0             0.0           0.0
# 4       23.71        0                0       0            28.0           0.0
# ...       ...      ...              ...     ...             ...           ...
# 319790  27.41        1                0       0             7.0           0.0
# 319791  29.84        1                0       0             0.0           0.0
# 319792  24.24        0                0       0             0.0           0.0
# 319793  32.81        0                0       0             0.0           0.0
# 319794  46.56        0                0       0             0.0           0.0
#
# ...

# %%
Y =df['HeartDisease']
Y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 319790    1
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: HeartDisease, Length: 319795, dtype: int64

# %%
### Train Test Split
from sklearn.model_selection import train_test_split,RandomizedSearchCV
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state = 0, test_size = 0.25)

# %% [markdown]
# # Decision Tree Classifier

# %%
#Model
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score
DTC = DecisionTreeClassifier()

# %%
DTC.fit(X_train,Y_train)
Y_pred= DTC.predict(X_test)
accuracy_score(Y_test,Y_pred)
# Out:
# 0.864501119463658

# %%
f1_score(Y_test,Y_pred)
# Out:
# 0.23802489976788352

# %%
precision_score(Y_test,Y_pred)
# Out:
# 0.2284942606347063

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cf = confusion_matrix(Y_test,Y_pred)
cf
# Out:
# array([[67424,  5713],
#        [ 5120,  1692]], dtype=int64)

# %%
import pickle
file = open("DTC.pkl","wb")
pickle.dump(DTC,file)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
Logreg = LogisticRegression(solver='newton-cg')

# %%
Logreg.fit(X_train,Y_train)
# Out:
# LogisticRegression(solver='newton-cg')

# %%
Y_pred = Logreg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cf = confusion_matrix(Y_test,Y_pred)
cf
# Out:
# array([[72621,   516],
#        [ 6206,   606]], dtype=int64)

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9159213998924314

# %%
import pickle
file = open("Logreg.pkl","wb")
pickle.dump(Logreg,file)

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')
